    [2.553, 1.031], [2.562, 1.036], [2.571, 1.041], [2.581, 1.046], [2.59, 1.051],
    [2.6, 1.056], [2.609, 1.061], [2.618, 1.066], [2.628, 1.071], [2.637, 1.076],
    [2.646, 1.081], [2.656, 1.086], [2.665, 1.091], [2.674, 1.096], [2.683, 1.101],
    [2.693, 1.106], [2.702, 1.111], [2.711, 1.116], [2.721, 1.121], [2.739, 1.131],
    [2.749, 1.136], [2.758, 1.141], [2.767, 1.146], [2.777, 1.151], [2.786, 1.156],
    [2.796, 1.161], [2.805, 1.166], [2.815, 1.171], [2.824, 1.176], [2.834, 1.181],
    [2.844, 1.186], [2.854, 1.191], [2.863, 1.196], [2.873, 1.201], [2.883, 1.206],
    [2.894, 1.211], [2.904, 1.216], [2.914, 1.221], [2.925, 1.226], [2.936, 1.231],
    [2.947, 1.236], [2.959, 1.241], [2.971, 1.246], [2.983, 1.251], [2.996, 1.256],
    [3.009, 1.261], [3.024, 1.266], [3.04, 1.271], [3.059, 1.276], [3.081, 1.281],
    [3.12, 1.286]
]

# Μετατροπή των δεδομένων σε πίνακα
data = np.array(data)

# Διαχωρισμός των τιμών k και E(k)
k_values = data[:, 0]
E_values = data[:, 1]

# Υπολογισμός πρώτης παραγώγου χρησιμοποιώντας την κεντρική διαφορά
E_prime = np.gradient(E_values, k_values)

# Υπολογισμός δεύτερης παραγώγου χρησιμοποιώντας την κεντρική διαφορά στην πρώτη παράγωγο
E_double_prime = np.gradient(E_prime, k_values)

# Εμφάνιση των αποτελεσμάτων σε DataFrame
df = pd.DataFrame({
    'k': k_values,
    'E(k)': E_values,
    'E\'(k)': E_prime,
    'E\'\'(k)': E_double_prime
})

import ace_tools as tools; tools.display_dataframe_to_user(name="Δεύτερη Παράγωγος", dataframe=df)

df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 69
#      61 # Εμφάνιση των αποτελεσμάτων σε DataFrame
#      62 df = pd.DataFrame({
#      63     'k': k_values,
#      64     'E(k)': E_values,
#      65     'E\'(k)': E_prime,
#      66     'E\'\'(k)': E_double_prime
#      67 })
# ---> 69 import ace_tools as tools; tools.display_dataframe_to_user(name="Δεύτερη Παράγωγος", dataframe=df)
#      71 df
#
# ModuleNotFoundError: No module named 'ace_tools'

# %%
# Υπολογισμός πρώτης παραγώγου χρησιμοποιώντας την κεντρική διαφορά
E_prime = np.gradient(E_values, k_values)

# Υπολογισμός δεύτερης παραγώγου χρησιμοποιώντας την κεντρική διαφορά στην πρώτη παράγωγο
E_double_prime = np.gradient(E_prime, k_values)

# Εμφάνιση των αποτελεσμάτων σε DataFrame
df = pd.DataFrame({
    'k': k_values,
    'E(k)': E_values,
    'E\'(k)': E_prime,
    'E\'\'(k)': E_double_prime
})

# Πλοτάρισμα
plt.figure(figsize=(12, 8))

plt.subplot(3, 1, 1)
plt.plot(k_values, E_values, label="E(k)")
plt.xlabel("k")
plt.ylabel("E(k)")
plt.legend()
plt.grid(True)

plt.subplot(3, 1, 2)
plt.plot(k_values, E_prime, label="E'(k)", color='orange')
plt.xlabel("k")
plt.ylabel("E'(k)")
plt.legend()
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(k_values, E_double_prime, label="E''(k)", color='green')
plt.xlabel("k")
plt.ylabel("E''(k)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
